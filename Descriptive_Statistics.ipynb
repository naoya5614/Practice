# %% [markdown]
# # 記述統計

# %%
#モジュールの読み込み
import numpy as np
import pandas as pd

height = np.array([170, 172, 180, 165, 177, 162, 159, 172, 168, 162])
print('身長', height)

weight = np.array([55, 65, 65, 59, 68, 44, 57, 70, 59, 55])
print('体重', weight)

sex = np.array(['女', '男', '男', '女', '男', '女', '女', '男', '女', '女'])
print('性別', sex)

sample_df = pd.DataFrame({
    'height' :height,
    'weight' :weight,
    'sex' :sex
})
print(sample_df)
# Out:
# 身長 [170 172 180 165 177 162 159 172 168 162]
# 体重 [55 65 65 59 68 44 57 70 59 55]
# 性別 ['女' '男' '男' '女' '男' '女' '女' '男' '女' '女']
#    height  weight sex
# 0     170      55   女
# 1     172      65   男
# 2     180      65   男
# 3     165      59   女
# 4     177      68   男
# 5     162      44   女
# 6     159      57   女
# 7     172      70   男
# 8     168      59   女
# 9     162      55   女

# %%
np.mean(sample_df) #np.meanで平均が計算計算される
# Out:
# height    168.7
# weight     59.7
# dtype: float64

# %%
sample_df.groupby(['sex']).mean() #男女別の平均を出す
# Out:
#          height     weight
# sex
# 女    164.333333  54.833333
# 男    175.250000  67.000000

# %%
np.sort(sample_df.height) #データをsortした
# Out:
# array([159, 162, 162, 165, 168, 170, 172, 172, 177, 180])

# %%
np.median(sample_df.height) #中央2つの平均
# Out:
# 169.0

# %%
sample_df.mode()
# Out:
#    height  weight  sex
# 0   162.0      55    女
# 1   172.0      59  NaN
# 2     NaN      65  NaN

# %%
import scipy as sp
from scipy import stats #さらに色々な関数を使えるように

# %%
sp.var(sample_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: scipy.var is deprecated and will be removed in SciPy 2.0.0, use numpy.var instead
#   """Entry point for launching an IPython kernel.
# height    41.81
# weight    53.01
# dtype: float64

# %%
def my_var(x):
  var = np.sum((x - np.mean(x))**2)/(len(x) - 1)
  return var

my_var(sample_df.height)
# Out:
# 46.455555555555556

# %%
sp.var(sample_df, ddof=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: scipy.var is deprecated and will be removed in SciPy 2.0.0, use numpy.var instead
#   """Entry point for launching an IPython kernel.
# height    46.455556
# weight    58.900000
# dtype: float64

# %%
sp.std(sample_df, ddof=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: scipy.std is deprecated and will be removed in SciPy 2.0.0, use numpy.std instead
#   """Entry point for launching an IPython kernel.
# height    6.815831
# weight    7.674634
# dtype: float64

# %%
print(stats.scoreatpercentile(sample_df.height,25))
print(stats.scoreatpercentile(sample_df.height,50))
print(stats.scoreatpercentile(sample_df.height,75))
# Out:
# 162.75
# 169.0
# 172.0

# %%
a0 =np.array(['A', 'B', 'C', 'D', 'E'])
a1 =np.array([150, 160, 175, 130, 155])
a2 =np.array([100, 130, 150, 90, 130])

bp_df = pd.DataFrame({
    '患者' :a0,
    '投薬前血圧' : a1,
    '投薬後血圧' : a2
})
print(bp_df)
# Out:
#   患者  投薬前血圧  投薬後血圧
# 0  A    150    100
# 1  B    160    130
# 2  C    175    150
# 3  D    130     90
# 4  E    155    130

# %%
a3 = np.array(['A', 'B', 'C', 'D', 'E', 'A', 'B', 'C', 'D', 'E'])
a4 = np.array([150, 160, 175, 130, 155, 100, 130, 150, 90, 130])
a5 = np.array(['前', '後'])
a6 = np.repeat(a5, [5, 5], axis=0)

tidybp_df = pd.DataFrame({
    '患者' :a3,
    '血圧' :a4,
    '状態' :a6
})
print(tidybp_df)
# Out:
#   患者   血圧 状態
# 0  A  150  前
# 1  B  160  前
# 2  C  175  前
# 3  D  130  前
# 4  E  155  前
# 5  A  100  後
# 6  B  130  後
# 7  C  150  後
# 8  D   90  後
# 9  E  130  後

# %%
b1 = np.repeat(['札幌', '東京', '神戸'], 3)
b2 = np.array(['6時', '12時', '18時']*3)
b3 = np.array(['晴れ', '晴れ', '晴れ', '曇り', '雨', '雨', '雨', '曇り', '晴れ'])

tidyweather_df = pd.DataFrame({
    '地点' :b1,
    '時刻' :b2,
    '天候' :b3
})
print(tidyweather_df)
# Out:
#    地点   時刻  天候
# 0  札幌   6時  晴れ
# 1  札幌  12時  晴れ
# 2  札幌  18時  晴れ
# 3  東京   6時  曇り
# 4  東京  12時   雨
# 5  東京  18時   雨
# 6  神戸   6時   雨
# 7  神戸  12時  曇り
# 8  神戸  18時  晴れ

# %%
#ライブラリなどの準備
import numpy as np
import pandas as pd
#表示桁数をいじる
# %precision 3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#折れ線グラフ
#正規分布に従う10個の乱数x, yの生成
from numpy.random import randn
x = randn(10)
y = randn(10)
print(x)
print(y)

#線グラフの描画
plt.plot(x, color = "orange")
plt.xlabel("x")
plt.plot(y, color = "blue")
plt.ylabel("y")
plt.title("line plot")
plt.show()
# Out:
# [-0.09   1.512 -0.941  0.859 -0.433  1.096 -0.782 -0.708 -0.248 -0.341]
# [ 0.628 -0.655 -0.686 -0.579  0.611 -0.515  0.091 -0.355  0.371  0.511]

# %%
import seaborn as sns
#正規乱数を100個生成
from numpy.random import normal
x = normal(loc=30, scale=10, size=100)
print(x)

#seabornでヒストグラム作成(kdeはカーネル密度推定)
sns.distplot(x, bins=5, color='black', kde=True)
# Out:
# [40.106 35.623 35.161 30.023 20.61  33.48  27.568 26.422 22.646 22.61
#  28.922 46.475 15.583 38.337 26.902 39.89  18.127  9.907 16.462 15.522
#  34.236 37.693 18.675  8.777 19.191 24.88  26.987 29.037 32.044 18.763
#  25.157 37.042 34.735 24.147 31.326 25.413 25.581 30.055 20.589 14.159
#  39.601 38.496 28.394 19.49  26.113 35.369 23.143 33.411 20.355 19.658
#  35.233 51.303 26.71  36.567 43.043 27.51  11.004 30.803 35.998 29.837
#  28.146 42.449 38.832 28.063 38.22  13.804 39.286 29.833 23.48  32.354
#  36.553 20.447 24.085 14.282 14.528 36.5   35.804 35.81  12.924 48.393
#  20.124 30.063 35.535 20.032 19.373 21.928 18.416 29.422 25.587 37.214
#  41.86  33.047 33.149 29.177 38.905 51.369 31.77  32.752 27.896 32.946]
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#irisデータのダウンロードと確認
iris = sns.load_dataset('iris')
iris.head(n = 5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.groupby("species").mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
#散布図の作成(joint plot)
sns.jointplot(x=iris.sepal_length, y=iris.sepal_width, data=iris)

# %%
sns.pairplot(iris, hue="species", palette="gray")

# %%
sns.boxplot(x = 'species', y='sepal_length', data=iris)

# %%
sns.violinplot(x = 'species', y='sepal_length', data=iris, palette='colorblind')

# %%
print(tidyweather_df)
# Out:
#    地点   時刻  天候
# 0  札幌   6時  晴れ
# 1  札幌  12時  晴れ
# 2  札幌  18時  晴れ
# 3  東京   6時  曇り
# 4  東京  12時   雨
# 5  東京  18時   雨
# 6  神戸   6時   雨
# 7  神戸  12時  曇り
# 8  神戸  18時  晴れ

# %%
import scipy as sp
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 7, 5, 2, 1])
sns.jointplot(x, y)

sp.corrcoef(x, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: scipy.corrcoef is deprecated and will be removed in SciPy 2.0.0, use numpy.corrcoef instead
# array([[ 1.  , -0.99],
#        [-0.99,  1.  ]])

# %%
x = np.array([400, 500, 600, 400, 450, 350, 500, 600, 700])
y = np.repeat(['Kobe', 'Kagoshima', 'Osaka'], 3)

salary_df = pd.DataFrame({
    'salary' : x,
    'place' : y
})

print(salary_df)
sns.boxplot(x='place', y='salary', data=salary_df)
# Out:
#    salary      place
# 0     400       Kobe
# 1     500       Kobe
# 2     600       Kobe
# 3     400  Kagoshima
# 4     450  Kagoshima
# 5     350  Kagoshima
# 6     500      Osaka
# 7     600      Osaka
# 8     700      Osaka

# %%
#全体平均の計算
mu = sp.mean(salary_df.salary)
print('全体平均', mu)

level_mu = np.repeat([500, 400, 600], 3)
print('水準平均', level_mu)

#級間変動
S_B = sp.sum((level_mu - mu)**2)
print('級間変動', S_B)

#級内変動
residuals = salary_df.salary - level_mu
print('残差', residuals)
S_W = sp.sum(residuals**2)
print('級内変動', S_W)

#相関比
eta2 = (S_B)/(S_B + S_W)
print('相関比', eta2)
# Out:
# 全体平均 500.0
# 水準平均 [500 500 500 400 400 400 600 600 600]
# 級間変動 60000.0
# 残差 0   -100
# 1      0
# 2    100
# 3      0
# 4     50
# 5    -50
# 6   -100
# 7      0
# 8    100
# Name: salary, dtype: int64
# 級内変動 45000
# 相関比 0.5714285714285714
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: scipy.sum is deprecated and will be removed in SciPy 2.0.0, use numpy.sum instead
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: scipy.sum is deprecated and will be removed in SciPy 2.0.0, use numpy.sum instead
#   from ipykernel import kernelapp as app

# %%
#偏差平方和の計算
np.sum((salary_df.salary - mu)**2)
# Out:
# 105000.000

# %%
sample_cross = np.array([[30, 20],
                          [10, 60]])

#期待度数表の作成
ex_cross = np.array([[40*50/120, 80*50/120],
                     [40*70/120, 80*70/120]])
print(ex_cross)
# Out:
# [[16.667 33.333]
#  [23.333 46.667]]

# %%
#クラメール連関係数計算の続き
chi_table = (sample_cross - ex_cross)**2/ex_cross
print(chi_table)

chisq = np.sum(chi_table)
print('カイ二乗値', chisq)

r_c = np.sqrt(chisq/(np.sum(sample_cross)*(min(sample_cross.shape)-1)))
print('クラメールの連関係数', r_c)
# Out:
# [[10.667  5.333]
#  [ 7.619  3.81 ]]
# カイ二乗値 27.428571428571427
# クラメールの連関係数 0.47809144373375745

# %%
#scipyを使って、カイ二乗検定
from scipy import stats
sample_cross = np.array([[30, 20],
                        [10, 60]])
print(sample_cross)
sp.stats.chi2_contingency(sample_cross, correction=False)
# Out:
# [[30 20]
#  [10 60]]
# (27.429, 0.000, 1, array([[16.667, 33.333],
#         [23.333, 46.667]]))
